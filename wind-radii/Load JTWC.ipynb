# %%
import pandas as pd
from datetime import datetime
import numpy as np
from Utilities.metutils import convert
inputpath = r"X:\georisk\HaRIA_B_Wind\data\raw\from_jtwc\bsh"
filename = r"X:\georisk\HaRIA_B_Wind\data\raw\from_jtwc\bsh\bsh011985.txt"

# %%
def convertLatLon(strval: str) -> float:
    """
    Convert a string representing lat/lon values from '140S to -14.0, etc.
    :param str strval: string containing the latitude or longitude.
    :returns: Latitude/longitude as a float value.
    """
    hemi = strval[-1].upper()
    fval = float(strval[:-1]) / 10.
    if (hemi == 'S') | (hemi == 'W'):
        fval *= -1
    if (hemi == 'E') | (hemi == 'W'):
        fval = fval % 360
    return fval

# %%
DATEFORMAT = "%Y%m%d%H"
COLUNITS = ['', '', '', '', '', '', '', '', 'kts', 'hPa',
            '', 'nm', '', 'nm', 'nm', 'nm', 'nm', 'hPa', 'nm', 'nm', 'kts', 'nm',
            '', '', '', 'degrees', 'kts', '', '', '',
            '', '', '', '', '']
CONVERTERS = {
    'Number': lambda s: s.strip(' ,'),
    #"Datetime": lambda s: datetime.strptime(s.strip(' ,'), DATEFORMAT),
    "Latitude": lambda s: float(convertLatLon(s.strip(' ,'))),
    "Longitude": lambda s: float(convertLatLon(s.strip(' ,'))),
    "Windspeed": lambda s: float(s.strip(' ,') or 0),
    "Pressure": lambda s: float(s.strip(' ,') or 0),
    "Status": lambda s: s.strip(' ,'),
    "RAD": lambda s: float(s.strip(' ,') or 0),
    "WINDCODE": lambda s: s.strip(' ,'),
    "RAD1": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[13], 'km'),
    "RAD2": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[14], 'km'),
    "RAD3": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[15], 'km'),
    "RAD4": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[16], 'km'),
    "Poci": lambda s: float(s.strip(' ,') or 0),
    "Roci": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[18], 'km'),
    "rMax": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[19], 'km'),
    "SPEED": lambda s: float(s.strip(' ,') or 0.0),
}

# %%
def repairline(line, ncols):
    return x[:len(COLNAMES)] + [0]*(len(COLNAMES) - len(x))

# %%
COLNAMES = ['BASIN','Number', 'Datetime','TECHNUM', 'TECH', 'TAU',
            'Latitude', 'Longitude', 'Windspeed','Pressure', '']
df = pd.read_csv(filename, names=COLNAMES, delimiter=",",
                    parse_dates=[2], infer_datetime_format=True,
                    skipinitialspace=True, converters=CONVERTERS,
                    on_bad_lines=lambda x: x[:len(COLNAMES)] + ['Nan']*(len(COLNAMES) - len(x)), engine='python')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [19], line 3
#       1 COLNAMES = ['BASIN','Number', 'Datetime','TECHNUM', 'TECH', 'TAU',
#       2             'Latitude', 'Longitude', 'Windspeed','Pressure', '']
# ----> 3 df = pd.read_csv(filename, names=COLNAMES, delimiter=",",
#       4                     parse_dates=[2], infer_datetime_format=True,
#       5                     skipinitialspace=True, converters=CONVERTERS,
#       6                     on_bad_lines=lambda x: x[:len(COLNAMES)] + ['NA']*(len(COLNAMES) - len(x)), engine='python')
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\readers.py:1772, in TextFileReader.read(self, nrows)
#    1765 nrows = validate_integer("nrows", nrows)
#    1766 try:
#    1767     # error: "ParserBase" has no attribute "read"
#    1768     (
#    1769         index,
#    1770         columns,
#    1771         col_dict,
# -> 1772     ) = self._engine.read(  # type: ignore[attr-defined]
#    1773         nrows
#    1774     )
#    1775 except Exception:
#    1776     self.close()
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\python_parser.py:286, in PythonParser.read(self, rows)
#     283 alldata = self._rows_to_cols(content)
#     284 data, columns = self._exclude_implicit_index(alldata)
# --> 286 conv_data = self._convert_data(data)
#     287 columns, conv_data = self._do_date_conversions(columns, conv_data)
#     289 index, result_columns = self._make_index(
#     290     conv_data, alldata, columns, indexnamerow
#     291 )
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\python_parser.py:350, in PythonParser._convert_data(self, data)
#     347     clean_na_values = self.na_values
#     348     clean_na_fvalues = self.na_fvalues
# --> 350 return self._convert_to_ndarrays(
#     351     data,
#     352     clean_na_values,
#     353     clean_na_fvalues,
#     354     self.verbose,
#     355     clean_conv,
#     356     clean_dtypes,
#     357 )
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\base_parser.py:567, in ParserBase._convert_to_ndarrays(self, dct, na_values, na_fvalues, verbose, converters, dtypes)
#     557     warnings.warn(
#     558         (
#     559             "Both a converter and dtype were specified "
#    (...)
#     563         stacklevel=find_stack_level(inspect.currentframe()),
#     564     )
#     566 try:
# --> 567     values = lib.map_infer(values, conv_f)
#     568 except ValueError:
#     569     # error: Argument 2 to "isin" has incompatible type "List[Any]";
#     570     # expected "Union[Union[ExtensionArray, ndarray], Index, Series]"
#     571     mask = algorithms.isin(
#     572         values, list(na_values)  # type: ignore[arg-type]
#     573     ).view(np.uint8)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\_libs\lib.pyx:2919, in pandas._libs.lib.map_infer()
#
# Cell In [9], line 12, in <lambda>(s)
#       1 DATEFORMAT = "%Y%m%d%H"
#       2 COLUNITS = ['', '', '', '', '', '', '', '', 'kts', 'hPa',
#       3             '', 'nm', '', 'nm', 'nm', 'nm', 'nm', 'hPa', 'nm', 'nm', 'kts', 'nm',
#       4             '', '', '', 'degrees', 'kts', '', '', '',
#       5             '', '', '', '', '']
#       6 CONVERTERS = {
#       7     'Number': lambda s: s.strip(' ,'),
#       8     #"Datetime": lambda s: datetime.strptime(s.strip(' ,'), DATEFORMAT),
#       9     "Latitude": lambda s: float(convertLatLon(s.strip(' ,'))),
#      10     "Longitude": lambda s: float(convertLatLon(s.strip(' ,'))),
#      11     "Windspeed": lambda s: float(s.strip(' ,') or 0),
# ---> 12     "Pressure": lambda s: float(s.strip(' ,') or 0),
#      13     "Status": lambda s: s.strip(' ,'),
#      14     "RAD": lambda s: float(s.strip(' ,') or 0),
#      15     "WINDCODE": lambda s: s.strip(' ,'),
#      16     "RAD1": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[13], 'km'),
#      17     "RAD2": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[14], 'km'),
#      18     "RAD3": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[15], 'km'),
#      19     "RAD4": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[16], 'km'),
#      20     "Poci": lambda s: float(s.strip(' ,') or 0),
#      21     "Roci": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[18], 'km'),
#      22     "rMax": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[19], 'km'),
#      23     "SPEED": lambda s: float(s.strip(' ,') or 0.0),
#      24 }
#
# AttributeError: 'NoneType' object has no attribute 'strip'

# %%
COLNAMES = ['BASIN','Number', 'Datetime','TECHNUM', 'TECH', 'TAU', 'Latitude', 'Longitude', 'Windspeed','Pressure', ]

df = pd.read_csv(filename, names=COLNAMES, delimiter=",",
                             parse_dates=[2], infer_datetime_format=True,
                             skipinitialspace=True, converters=CONVERTERS,
                              on_bad_lines='warn')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [20], line 3
#       1 COLNAMES = ['BASIN','Number', 'Datetime','TECHNUM', 'TECH', 'TAU', 'Latitude', 'Longitude', 'Windspeed','Pressure', ]
# ----> 3 df = pd.read_csv(filename, names=COLNAMES, delimiter=",",
#       4                              parse_dates=[2], infer_datetime_format=True,
#       5                              skipinitialspace=True, converters=CONVERTERS,
#       6                               on_bad_lines='warn')
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\readers.py:1772, in TextFileReader.read(self, nrows)
#    1765 nrows = validate_integer("nrows", nrows)
#    1766 try:
#    1767     # error: "ParserBase" has no attribute "read"
#    1768     (
#    1769         index,
#    1770         columns,
#    1771         col_dict,
# -> 1772     ) = self._engine.read(  # type: ignore[attr-defined]
#    1773         nrows
#    1774     )
#    1775 except Exception:
#    1776     self.close()
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:243, in CParserWrapper.read(self, nrows)
#     241 try:
#     242     if self.low_memory:
# --> 243         chunks = self._reader.read_low_memory(nrows)
#     244         # destructive to chunks
#     245         data = _concatenate_chunks(chunks)
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\_libs\parsers.pyx:890, in pandas._libs.parsers.TextReader._read_rows()
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\_libs\parsers.pyx:1016, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File C:\W10Dev\Anaconda3\envs\bayes\lib\site-packages\pandas\_libs\parsers.pyx:2027, in pandas._libs.parsers._apply_converter()
#
# Cell In [9], line 12, in <lambda>(s)
#       1 DATEFORMAT = "%Y%m%d%H"
#       2 COLUNITS = ['', '', '', '', '', '', '', '', 'kts', 'hPa',
#       3             '', 'nm', '', 'nm', 'nm', 'nm', 'nm', 'hPa', 'nm', 'nm', 'kts', 'nm',
#       4             '', '', '', 'degrees', 'kts', '', '', '',
#       5             '', '', '', '', '']
#       6 CONVERTERS = {
#       7     'Number': lambda s: s.strip(' ,'),
#       8     #"Datetime": lambda s: datetime.strptime(s.strip(' ,'), DATEFORMAT),
#       9     "Latitude": lambda s: float(convertLatLon(s.strip(' ,'))),
#      10     "Longitude": lambda s: float(convertLatLon(s.strip(' ,'))),
#      11     "Windspeed": lambda s: float(s.strip(' ,') or 0),
# ---> 12     "Pressure": lambda s: float(s.strip(' ,') or 0),
#      13     "Status": lambda s: s.strip(' ,'),
#      14     "RAD": lambda s: float(s.strip(' ,') or 0),
#      15     "WINDCODE": lambda s: s.strip(' ,'),
#      16     "RAD1": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[13], 'km'),
#      17     "RAD2": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[14], 'km'),
#      18     "RAD3": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[15], 'km'),
#      19     "RAD4": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[16], 'km'),
#      20     "Poci": lambda s: float(s.strip(' ,') or 0),
#      21     "Roci": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[18], 'km'),
#      22     "rMax": lambda s: convert(float(s.strip(' ,') or 0), COLUNITS[19], 'km'),
#      23     "SPEED": lambda s: float(s.strip(' ,') or 0.0),
#      24 }
#
# ValueError: could not convert string to float: 'XX'
